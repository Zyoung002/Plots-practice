# %%
#libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
#create a dataframe
#same parent folder 
original_penguins_data = pd.read_csv('RawData/penguins.csv')
original_penguins_data
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
original_penguins_data.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
print(original_penguins_data.columns)
print(original_penguins_data.shape)
print(original_penguins_data.dtypes)
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')
# (344, 7)
# species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# dtype: object

# %%
original_penguins_data['species'].unique()
original_penguins_data
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
original_penguins_data['sex'].unique()

nan_count = original_penguins_data.isna().sum()
nan_count
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
nan_values = original_penguins_data[original_penguins_data.isna().any(axis=1)]
nan_values
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 8    Adelie  Torgersen            34.1           18.1              193.0
# 9    Adelie  Torgersen            42.0           20.2              190.0
# 10   Adelie  Torgersen            37.8           17.1              186.0
# 11   Adelie  Torgersen            37.8           17.3              180.0
# 47   Adelie      Dream            37.5           18.9              179.0
# 246  Gentoo     Biscoe            44.5           14.3              216.0
# 286  Gentoo     Biscoe            46.2           14.4              214.0
# 324  Gentoo     Biscoe            47.3           13.8              216.0
# 336  Gentoo     Biscoe            44.5           15.7              217.0
# 339  Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g  sex
# 3            NaN  NaN
# 8         3475.0  NaN
# ...

# %%
null_values_zero_df = original_penguins_data.copy()
null_values_zero_df['bill_depth_mm'] = null_values_zero_df[['bill_depth_mm']].fillna(0)
null_values_zero_df['bill_length_mm'] = null_values_zero_df[['bill_length_mm']].fillna(0)
null_values_zero_df['bill_depth_mm'] = null_values_zero_df[['bill_depth_mm']].fillna(0)
null_values_zero_df['flipper_length_mm'] = null_values_zero_df[['flipper_length_mm']].fillna(0)
null_values_zero_df['body_mass_g'] = null_values_zero_df[['body_mass_g']].fillna(0)
null_values_zero_df['sex'] = null_values_zero_df[['sex']].fillna('UNK')

null_values_zero_df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             0.0            0.0                0.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             0.0            0.0                0.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
original_penguins_data.describe
# Out:
# <bound method NDFrame.describe of     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# ...

# %%
gentoo_df = null_values_zero_df.copy()

gentoo_df = original_penguins_data[original_penguins_data['species'] == 'Gentoo']
gentoo_df
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 220  Gentoo  Biscoe            46.1           13.2              211.0
# 221  Gentoo  Biscoe            50.0           16.3              230.0
# 222  Gentoo  Biscoe            48.7           14.1              210.0
# 223  Gentoo  Biscoe            50.0           15.2              218.0
# 224  Gentoo  Biscoe            47.6           14.5              215.0
# ..      ...     ...             ...            ...                ...
# 339  Gentoo  Biscoe             NaN            NaN                NaN
# 340  Gentoo  Biscoe            46.8           14.3              215.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 342  Gentoo  Biscoe            45.2           14.8              212.0
# 343  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 220       4500.0  FEMALE
# 221       5700.0    MALE
# 222       4450.0  FEMALE
# ...

# %%
#beefy_gentoo_df = gentoo_df.query("body_mass_g> 5000")
#beefy_gentoo_df
male_gentoo = gentoo_df.query("sex == 'MALE'")
female_gentoo = gentoo_df.query("sex == 'FEMALE'")
print(male_gentoo)
print(female_gentoo)
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 221  Gentoo  Biscoe            50.0           16.3              230.0
# 223  Gentoo  Biscoe            50.0           15.2              218.0
# 224  Gentoo  Biscoe            47.6           14.5              215.0
# 227  Gentoo  Biscoe            46.7           15.3              219.0
# 229  Gentoo  Biscoe            46.8           15.4              215.0
# ..      ...     ...             ...            ...                ...
# 333  Gentoo  Biscoe            51.5           16.3              230.0
# 335  Gentoo  Biscoe            55.1           16.0              230.0
# 337  Gentoo  Biscoe            48.8           16.2              222.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 343  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g   sex
# 221       5700.0  MALE
# 223       5700.0  MALE
# 224       5400.0  MALE
# 227       5200.0  MALE
# ...

# %%
species_flipper_average = original_penguins_data.groupby('species')['flipper_length_mm'].mean().reset_index().round(2)
print(species_flipper_average)
# Out:
#      species  flipper_length_mm
# 0     Adelie             189.95
# 1  Chinstrap             195.82
# 2     Gentoo             217.19

# %%
plt.bar(species_flipper_average['species'], species_flipper_average['flipper_length_mm'])
# Out:
# <BarContainer object of 3 artists>

# %%
plt.scatter(male_gentoo['body_mass_g'], male_gentoo['flipper_length_mm'])

# %%
plt.scatter(female_gentoo['body_mass_g'], female_gentoo['bill_length_mm'], label='Female')
plt.scatter(male_gentoo['body_mass_g'], male_gentoo['bill_length_mm'], label= 'Male')
plt.legend()

# %%
plt.scatter(female_gentoo['flipper_length_mm'], female_gentoo['body_mass_g'], label='Female')
plt.scatter(male_gentoo['bill_length_mm'], male_gentoo['flipper_length_mm'], label= 'Male')
plt.legend()

# %%
penguins_unique_values = []

unique_species = original_penguins_data['species'].unique()
unique_island  = original_penguins_data['island'].unique()
unique_sex = original_penguins_data['sex'].unique

penguins_unique_values= [unique_species, unique_island, unique_sex]

for unique in penguins_unique_values:
    print (unique, '\n')
# Out:
# ['Adelie' 'Chinstrap' 'Gentoo']
#
# ['Torgersen' 'Biscoe' 'Dream']
#
# <bound method Series.unique of 0        MALE
# 1      FEMALE
# 2      FEMALE
# 3         NaN
# 4      FEMALE
#         ...
# 339       NaN
# 340    FEMALE
# 341      MALE
# 342    FEMALE
# 343      MALE
# Name: sex, Length: 344, dtype: object>

# %%
# species breakdown (percentage)

# number of penguin species by island
#body mass by island
# size of males v females in all areas

# size difference by island
# flipper length for penguin species
# long bill length by species
# long bill lenght by species and by island
# mass has an impact on length and depth?

# %%
#species breakdown - counting penguins by species
#sex_breakdown = original_penguins_data.groupby('sex').agg({'sex' : 'count'})

sex_breakdown = pd.DataFrame(original_penguins_data['sex'].value_counts())
sex_breakdown.reset_index()
# Out:
#       sex  count
# 0    MALE    168
# 1  FEMALE    165

# %%
# Want to see the perc of males and femals x / total

original_df_length = 333
sex_breakdown['percentage'] = round((sex_breakdown['count'] / original_df_length) * 100, 2)

sex_breakdown
# Out:
#         count  percentage
# sex
# MALE      168       50.45
# FEMALE    165       49.55

# %%
sex_by_island = original_penguins_data.groupby(['sex', 'island']).agg('count')

# %%
sex_by_island = sex_by_island.reset_index()

sex_by_island
# Out:
#       sex     island  species  bill_length_mm  bill_depth_mm  \
# 0  FEMALE     Biscoe       80              80             80
# 1  FEMALE      Dream       61              61             61
# 2  FEMALE  Torgersen       24              24             24
# 3    MALE     Biscoe       83              83             83
# 4    MALE      Dream       62              62             62
# 5    MALE  Torgersen       23              23             23
#
#    flipper_length_mm  body_mass_g
# 0                 80           80
# 1                 61           61
# 2                 24           24
# 3                 83           83
# 4                 62           62
# 5                 23           23

# %%
sex_by_island.plot(x='sex', kind = 'bar')
# Out:
# <Axes: xlabel='sex'>
